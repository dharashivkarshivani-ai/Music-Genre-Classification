# %%
import tensorflow as tf

model = tf.keras.models.load_model("Trained_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
# ----> 3 X_test = np.load("X_test.npy")
#       4 y_test = np.load("y_test.npy")
#
# File e:\Music_Classification_System\venv\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X_test.npy'

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Model Loss:", loss)
print("Model Accuracy:", accuracy)
print("Model Accuracy (%):", accuracy * 100)

# %%
import tensorflow as tf
import numpy as np

# Load test data
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")

# Load your trained model
model = tf.keras.models.load_model("model.h5")   # change filename if needed

# Evaluate accuracy
loss, accuracy = model.evaluate(X_test, y_test)

print("Model Loss:", loss)
print("Model Accuracy:", accuracy)
print("Model Accuracy (%):", accuracy * 100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 import numpy as np
#       4 # Load test data
# ----> 5 X_test = np.load("X_test.npy")
#       6 y_test = np.load("y_test.npy")
#       8 # Load your trained model
#
# File e:\Music_Classification_System\venv\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X_test.npy'
